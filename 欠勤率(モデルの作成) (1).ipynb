# %% [markdown]
# # ロジスティック回帰モデルの作成

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator, TransformerMixin
import pickle

# %% [markdown]
# ##　データの読み込み

# %%
data_preprocessed = pd.read_csv("Absenteeism_preprocessed.csv")

# %%
data_preprocessed .head()
# Out:
#    Reason1  Reason2  Reason3  Reason4  Month Value  Day of the Week  \
# 0        0        0        0        1            7                1
# 1        0        0        0        0            7                1
# 2        0        0        0        1            7                2
# 3        1        0        0        0            7                3
# 4        0        0        0        1            7                3
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# 1                     118                13   50                  239.554
# 2                     179                51   38                  239.554
# 3                     279                 5   39                  239.554
# 4                     289                36   33                  239.554
#
#    Body Mass Index  Education  Children  Pets  Absenteeism Time in Hours
# 0               30          0         2     1                          4
# 1               31          0         1     0                          0
# 2               31          0         0     0                          2
# 3               24          0         2     0                          4
# 4               30          0         2     1                          2

# %% [markdown]
# ## ターゲットの作成

# %%
data_preprocessed["Absenteeism Time in Hours"].median()
# Out:
# 3.0

# %%
# 汎用性考慮
targets = np.where(data_preprocessed["Absenteeism Time in Hours"] > 
                   data_preprocessed["Absenteeism Time in Hours"].median(), 1, 0)

data_preprocessed["Excessive Absenteeism"] = targets

# %%
data_preprocessed
# Out:
#      Reason1  Reason2  Reason3  Reason4  Month Value  Day of the Week  \
# 0          0        0        0        1            7                1
# 1          0        0        0        0            7                1
# 2          0        0        0        1            7                2
# 3          1        0        0        0            7                3
# 4          0        0        0        1            7                3
# ..       ...      ...      ...      ...          ...              ...
# 695        1        0        0        0            5                2
# 696        1        0        0        0            5                2
# 697        1        0        0        0            5                3
# 698        0        0        0        1            5                3
# 699        0        0        0        1            5                3
#
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                       289                36   33                  239.554
# 1                       118                13   50                  239.554
# 2                       179                51   38                  239.554
# 3                       279                 5   39                  239.554
# 4                       289                36   33                  239.554
# ..                      ...               ...  ...                      ...
# 695                     179                22   40                  237.656
# 696                     225                26   28                  237.656
# 697                     330                16   28                  237.656
# 698                     235                16   32                  237.656
# 699                     291                31   40                  237.656
#
#      Body Mass Index  Education  Children  Pets  Absenteeism Time in Hours  \
# 0                 30          0         2     1                          4
# 1                 31          0         1     0                          0
# 2                 31          0         0     0                          2
# 3                 24          0         2     0                          4
# 4                 30          0         2     1                          2
# ..               ...        ...       ...   ...                        ...
# 695               22          1         2     0                          8
# 696               24          0         1     2                          3
# 697               25          1         0     0                          8
# 698               25          1         0     0                          2
# 699               25          0         1     1                          2
#
#      Excessive Absenteeism
# 0                        1
# 1                        0
# 2                        0
# 3                        1
# 4                        0
# ..                     ...
# 695                      1
# 696                      0
# 697                      1
# 698                      0
# 699                      0
#
# [700 rows x 16 columns]

# %% [markdown]
# ## データ割合の確認・作成

# %%
targets.sum() / targets.shape[0]
# Out:
# 0.45571428571428574

# %%
data_with_targets = data_preprocessed.drop(["Absenteeism Time in Hours", "Daily Work Load Average", "Distance to Work"], axis=1)

unscaled_inputs = data_with_targets.iloc[:, :-1]

# %% [markdown]
# ## データの標準化・分割

# %%
# 標準化
absenteeism_scaler = StandardScaler()

absenteeism_scaler.fit(unscaled_inputs)
scaled_inputs = absenteeism_scaler.transform(unscaled_inputs)

# %%
# カテゴリー変数は標準化から外す
class CustomScaler(BaseEstimator, TransformerMixin):

    def __init__(self, columns, copy=True, with_mean=True, with_std=True):
        self.scaler = StandardScaler(copy=copy, with_mean=with_mean, with_std=with_std)
        self.columns = columns
        self.mean_ = None
        self.var_ = None

    def fit(self, X, y=None):
        self.scaler.fit(X[self.columns], y)
        self.mean_ = np.mean(X[self.columns])
        self.var_ = np.var(X[self.columns])
        return self

    def transform(self, X, y=None, copy=None):
        init_col_order = X.columns
        X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)
        X_not_scaled = X.loc[:, ~X.columns.isin(self.columns)]
        return pd.concat([X_not_scaled, X_scaled], axis=1)[init_col_order]

# %%
unscaled_inputs.columns.values
# Out:
# array(['Reason1', 'Reason2', 'Reason3', 'Reason4', 'Month Value',
#        'Day of the Week', 'Transportation Expense', 'Age',
#        'Body Mass Index', 'Education', 'Children', 'Pets'], dtype=object)

# %%
#columns_to_scale = ['Month Value','Day of the Week', 'Transportation Expense', 'Distance to Work',
#      'Age', 'Daily Work Load Average', 'Body Mass Index', 'Education',
#      'Children', 'Pets']

columns_to_omit = ['Reason1', 'Reason2', 'Reason3', 'Reason4', "Daily Work Load Average", "Distance to Work"]
columns_to_scale = [x for x in unscaled_inputs.columns.values if x not in columns_to_omit]

absenteeism_scaler = CustomScaler(columns_to_scale)
absenteeism_scaler.fit(unscaled_inputs)
scaled_inputs = absenteeism_scaler.transform(unscaled_inputs)
# Out:
# /opt/anaconda3/envs/new_all/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
scaled_inputs
# Out:
#      Reason1  Reason2  Reason3  Reason4  Month Value  Day of the Week  \
# 0          0        0        0        1     0.182726        -0.683704
# 1          0        0        0        0     0.182726        -0.683704
# 2          0        0        0        1     0.182726        -0.007725
# 3          1        0        0        0     0.182726         0.668253
# 4          0        0        0        1     0.182726         0.668253
# ..       ...      ...      ...      ...          ...              ...
# 695        1        0        0        0    -0.388293        -0.007725
# 696        1        0        0        0    -0.388293        -0.007725
# 697        1        0        0        0    -0.388293         0.668253
# 698        0        0        0        1    -0.388293         0.668253
# 699        0        0        0        1    -0.388293         0.668253
#
#      Transportation Expense       Age  Body Mass Index  Education  Children  \
# 0                  1.005844 -0.536062         0.767431  -0.447980  0.880469
# 1                 -1.574681  2.130803         1.002633  -0.447980 -0.019280
# 2                 -0.654143  0.248310         1.002633  -0.447980 -0.919030
# 3                  0.854936  0.405184        -0.643782  -0.447980  0.880469
# 4                  1.005844 -0.536062         0.767431  -0.447980  0.880469
# ..                      ...       ...              ...        ...       ...
# 695               -0.654143  0.562059        -1.114186   2.232242  0.880469
# 696                0.040034 -1.320435        -0.643782  -0.447980 -0.019280
# 697                1.624567 -1.320435        -0.408580   2.232242 -0.919030
# 698                0.190942 -0.692937        -0.408580   2.232242 -0.919030
# 699                1.036026  0.562059        -0.408580  -0.447980 -0.019280
#
#          Pets
# 0    0.268487
# 1   -0.589690
# 2   -0.589690
# 3   -0.589690
# 4    0.268487
# ..        ...
# 695 -0.589690
# 696  1.126663
# 697 -0.589690
# 698 -0.589690
# 699  0.268487
#
# [700 rows x 12 columns]

# %%
# 分割
x_train, x_test, y_train, y_test = train_test_split(scaled_inputs, targets, train_size=0.8, random_state=20)

# %% [markdown]
# ## モデル訓練

# %%
reg = LogisticRegression()
reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# 正確性・切片・重みの確認
print(reg.score(x_train, y_train), reg.intercept_, reg.coef_)
# Out:
# 0.775 [-1.68909209] [[ 2.80062254  0.93512933  3.09812821  0.85396822  0.16636314 -0.08504146
#    0.61123775 -0.16417463  0.26880304 -0.08070247  0.36072307 -0.2863671 ]]

# %%
unscaled_inputs.columns.values
# Out:
# array(['Reason1', 'Reason2', 'Reason3', 'Reason4', 'Month Value',
#        'Day of the Week', 'Transportation Expense', 'Age',
#        'Body Mass Index', 'Education', 'Children', 'Pets'], dtype=object)

# %%
#DataFrameの作成
feature_name = unscaled_inputs.columns.values

# 重みの追加
summary_table = pd.DataFrame(columns=["Feature name"], data=feature_name)
summary_table["Coefficient"] = np.transpose(reg.coef_)

# 切片の追加
summary_table.index = summary_table.index+1
summary_table.loc[0] = ["Intercept", reg.intercept_[0]]
summary_tabel = summary_table.sort_index()
summary_tabel
# Out:
#               Feature name  Coefficient
# 0                Intercept    -1.689092
# 1                  Reason1     2.800623
# 2                  Reason2     0.935129
# 3                  Reason3     3.098128
# 4                  Reason4     0.853968
# 5              Month Value     0.166363
# 6          Day of the Week    -0.085041
# 7   Transportation Expense     0.611238
# 8                      Age    -0.164175
# 9          Body Mass Index     0.268803
# 10               Education    -0.080702
# 11                Children     0.360723
# 12                    Pets    -0.286367

# %% [markdown]
# ## オッズ比

# %%
summary_table["Odds_ration"] = np.exp(summary_table.Coefficient)
summary_table.sort_values("Odds_ration", ascending=False)
# Out:
#               Feature name  Coefficient  Odds_ration
# 3                  Reason3     3.098128    22.156440
# 1                  Reason1     2.800623    16.454887
# 2                  Reason2     0.935129     2.547543
# 4                  Reason4     0.853968     2.348950
# 7   Transportation Expense     0.611238     1.842711
# 11                Children     0.360723     1.434366
# 9          Body Mass Index     0.268803     1.308397
# 5              Month Value     0.166363     1.181002
# 10               Education    -0.080702     0.922468
# 6          Day of the Week    -0.085041     0.918474
# 8                      Age    -0.164175     0.848594
# 12                    Pets    -0.286367     0.750987
# 0                Intercept    -1.689092     0.184687

# %% [markdown]
# ## モデルのテスト

# %%
reg.score(x_test, y_test)
# Out:
# 0.7428571428571429

# %%
predicted_proba = reg.predict_proba(x_test)
predicted_proba[:, 1]
# Out:
# array([0.26373731, 0.39160367, 0.58860623, 0.19676771, 0.92764658,
#        0.68351633, 0.68714466, 0.86660494, 0.20233182, 0.24943004,
#        0.51894341, 0.80186969, 0.92245313, 0.28939733, 0.69397129,
#        0.42448726, 0.45966739, 0.42882618, 0.61862957, 0.95159492,
#        0.30167924, 0.20601201, 0.60429258, 0.57649737, 0.73397239,
#        0.2433699 , 0.48602119, 0.1311796 , 0.80058986, 0.21557405,
#        0.37388233, 0.68672223, 0.69157426, 0.54259813, 0.20601201,
#        0.50736116, 0.21010621, 0.74391665, 0.43587519, 0.59254326,
#        0.22720279, 0.43378738, 0.2163992 , 0.39603995, 0.81547127,
#        0.57038357, 0.69134841, 0.2750505 , 0.20235228, 0.18218452,
#        0.59170996, 0.34222359, 0.67095173, 0.28613944, 0.85018117,
#        0.47112344, 0.89016876, 0.25488056, 0.31794827, 0.31578629,
#        0.71918305, 0.66038142, 0.31050759, 0.78748791, 0.19823823,
#        0.26763444, 0.08235605, 0.22982263, 0.72858899, 0.32997026,
#        0.21010621, 0.2943376 , 0.90845154, 0.43773179, 0.61937475,
#        0.21557405, 0.78667128, 0.70389084, 0.76583284, 0.6810796 ,
#        0.24521378, 0.07978283, 0.22353076, 0.72955535, 0.41392686,
#        0.12286335, 0.69951721, 0.56240414, 0.23333765, 0.67422424,
#        0.16221821, 0.12312282, 0.22371455, 0.29076214, 0.22853063,
#        0.86682692, 0.27306343, 0.78606879, 0.22632815, 0.23426794,
#        0.62817739, 0.69895483, 0.70888004, 0.69698626, 0.46868792,
#        0.51863355, 0.25461813, 0.84563021, 0.77670637, 0.15145275,
#        0.07308098, 0.90322372, 0.64390967, 0.35420505, 0.55277595,
#        0.60215213, 0.80359272, 0.80396961, 0.52444395, 0.29957929,
#        0.23701256, 0.17141733, 0.82892486, 0.4765281 , 0.21557405,
#        0.38442031, 0.19835107, 0.11938634, 0.74884832, 0.31392603,
#        0.65744572, 0.20765052, 0.32099773, 0.34450402, 0.29260696,
#        0.50985737, 0.44296046, 0.30295204, 0.25793994, 0.43773179])

# %% [markdown]
# ## モデルの保存

# %%
with open("model", "wb") as file:
    pickle.dump(reg, file)

with open("scaler", "wb") as file:
    pickle.dump(absenteeism_scaler, file)
